# %%
from google.colab import drive
import os
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'linear-bounty-276101'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://media-memorability-embeddings-test-1/

# %%
bucket_name = 'media-memorability-embeddings-test-1'
# initial upload - all data
# !gsutil -m cp -r /content/drive/My\ Drive/Colab\ Notebooks/CA684\ ML\ Assignment/* gs://{bucket_name}/

# uploading preprocessed captions
# !gsutil -m cp -r /content/drive/My\ Drive/Colab\ Notebooks/CA684\ ML\ Assignment/processed_caption.csv gs://{bucket_name}/
# Out:
# Copying file:///content/drive/My Drive/Colab Notebooks/CA684 ML Assignment/processed_caption.csv [Content-Type=text/csv]...
# \
# Operation completed over 1 objects/1.2 MiB.
